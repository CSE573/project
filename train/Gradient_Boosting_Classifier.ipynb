# %%
import pandas as pd
import os
import matplotlib.pyplot as plt

# %%
cwd = os.getcwd()
files = os.listdir(cwd)

for file in files:
  print(file)

df = pd.read_csv('sample_data/income_report.csv')


df.describe()
# Out:
# .config
# sample_data
#                 age        fnlwgt   education-num   capital-gain  \
# count  32561.000000  3.256100e+04    32561.000000   32561.000000
# mean      38.581647  1.897784e+05       10.080679    1077.648844
# std       13.640433  1.055500e+05        2.572720    7385.292085
# min       17.000000  1.228500e+04        1.000000       0.000000
# 25%       28.000000  1.178270e+05        9.000000       0.000000
# 50%       37.000000  1.783560e+05       10.000000       0.000000
# 75%       48.000000  2.370510e+05       12.000000       0.000000
# max       90.000000  1.484705e+06       16.000000   99999.000000
#
#         capital-loss   hours-per-week
# count   32561.000000     32561.000000
# mean       87.303830        40.437456
# std       402.960219        12.347429
# min         0.000000         1.000000
# 25%         0.000000        40.000000
# 50%         0.000000        40.000000
# 75%         0.000000        45.000000
# max      4356.000000        99.000000

# %%
# Out:
# Empty DataFrame
# Columns: [age,  workclass,  fnlwgt,  education,  education-num,  marital-status,  occupation,  relationship,  race,  sex,  capital-gain,  capital-loss,  hours-per-week,  native-country,  income ]
# Index: []

# %%
#num_dirty_rows = df.apply(lambda x: x.str.contains('\?').any(), axis=1).sum()

# Print the result:
#print(f"Number of rows with dirty character: {num_dirty_rows}")
# Out:
# Number of rows with dirty character: 2399

# %%
# Filter rows where income is greater than "50K":
filtered_df = df[df[' income '] == ' >50K']

# Group filtered DataFrame by sex and count occurrences:
sex_counts = filtered_df[' sex'].value_counts()
colors_list = ['lightcoral', 'gold']  # Define custom colors
# Create a pie chart:
plt.figure(figsize=(6, 4))
plt.pie(
    sex_counts,
    autopct="%1.1f%%",
    labels=None,  # Hide labels inside the piechart
    startangle=90,  # Rotate starting angle
    colors=colors_list,  # Use custom colors
)

plt.legend(labels=sex_counts.index, loc='upper left')
plt.title("Pie Chart of Males and Females with income >50K", fontsize=12)
plt.axis('equal')  # Equal aspect ratio ensures a circular pie chart
plt.ylabel('Sex')

# Display the chart:
plt.show()

# %%
# Extract the race column:
race_series = filtered_df[" race"]

# Count occurrences of each race:
race_counts = race_series.value_counts(ascending=False)

# Create the bar chart:
plt.figure(figsize=(8, 5))  # Set figure size

colors_list = ['yellowgreen', 'lightcoral', 'lightskyblue', 'gold', 'lightgray']  # Define custom colors

plt.bar(race_counts.index, race_counts.values, color=colors_list)

# Add labels and title:
plt.xlabel("Race")
plt.ylabel("Count")
plt.title("Racial distribution of adults with income >50K")

# Add data labels on top of bars:
for i in range(race_counts.shape[0]):
    plt.text(i, race_counts.values[i], race_counts.values[i], ha='center', va='bottom')

# Improve aesthetics:
plt.tight_layout()  # Reduce whitespace around the chart

# Display the chart:
plt.show()
